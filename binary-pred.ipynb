# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from catboost import CatBoostClassifier, Pool
from xgboost import XGBClassifier
from xgboost.callback import EarlyStopping
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, cross_validate, StratifiedKFold
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import VotingClassifier, StackingClassifier
from sklearn.ensemble import HistGradientBoostingClassifier
import optuna
from catboost import Pool, CatBoostClassifier, cv

# %% [markdown]
# <div style="background-color: #DDDDDD; padding: 20px; border-radius: 20px; border: 2px solid black;">
#     <h1 style="font-family:  'Garamond', 'Lucida Sans', sans-serif; text-align: center; color: black; font-weight: bold; font-size: 42px;">
#     Read Data
#     </h1>
# </div>

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train.columns
# Out:
# Index(['id', 'age', 'height(cm)', 'weight(kg)', 'waist(cm)', 'eyesight(left)',
#        'eyesight(right)', 'hearing(left)', 'hearing(right)', 'systolic',
#        'relaxation', 'fasting blood sugar', 'Cholesterol', 'triglyceride',
#        'HDL', 'LDL', 'hemoglobin', 'Urine protein', 'serum creatinine', 'AST',
#        'ALT', 'Gtp', 'dental caries', 'smoking'],
#       dtype='object')

# %% [markdown]
# <div style="background-color: #DDDDDD; padding: 20px; border-radius: 20px; border: 2px solid black;">
#     <h1 style="font-family:  'Garamond', 'Lucida Sans', sans-serif; text-align: center; color: black; font-weight: bold; font-size: 42px;">
#     Feature Extraction
#     </h1>
# </div>

# %% [markdown]
# train["BMI"] = train["weight(kg)"] / (train["height(cm)"]/100)**2
# train["HDL-LDL Ratio"] = train["HDL"] / train["LDL"]
# train["HDL-triglyceride Ratio"] = train["HDL"] / train["triglyceride"]
# train["LDL-triglyceride Ratio"] = train["LDL"] / train["triglyceride"]
# train["Liver Enzyme Ratio"] = train["AST"] / train["ALT"]
# train['average_eyesight'] = (train['eyesight(left)'] + train['eyesight(right)']) / 2
# train['hearing_health_score'] = (train['hearing(left)'] + train['hearing(right)']) / 2
# train['cardiovascular_health_score'] = train['systolic'] - train['relaxation'] + (train['HDL'] - train['LDL']) + train['hemoglobin']
# train['liver_function_score'] = train['AST'] + train['ALT']
# train['metabolism_score'] = train['fasting blood sugar'] - train['Cholesterol']
#
#
# test["BMI"] = test["weight(kg)"] / (test["height(cm)"]/100)**2
# test["HDL-LDL Ratio"] = test["HDL"] / test["LDL"]
# test["HDL-triglyceride Ratio"] = test["HDL"] / test["triglyceride"]
# test["LDL-triglyceride Ratio"] = test["LDL"] / test["triglyceride"]
# test["Liver Enzyme Ratio"] = test["AST"] / test["ALT"]
# test['average_eyesight'] = (test['eyesight(left)'] + test['eyesight(right)']) / 2
# test['hearing_health_score'] = (test['hearing(left)'] + test['hearing(right)']) / 2
# test['cardiovascular_health_score'] = test['systolic'] - test['relaxation'] + (test['HDL'] - test['LDL']) + test['hemoglobin']
# test['liver_function_score'] = test['AST'] + test['ALT']
# test['metabolism_score'] = test['fasting blood sugar'] - test['Cholesterol']

# %%
def create_extra_features(df):
    best = np.where(df['hearing(left)'] < df['hearing(right)'], 
                    df['hearing(left)'],  df['hearing(right)'])
    worst = np.where(df['hearing(left)'] < df['hearing(right)'], 
                     df['hearing(right)'],  df['hearing(left)'])
    df['hearing(left)'] = best - 1
    df['hearing(right)'] = worst - 1
    
    df['eyesight(left)'] = np.where(df['eyesight(left)'] > 9, 0, df['eyesight(left)'])
    df['eyesight(right)'] = np.where(df['eyesight(right)'] > 9, 0, df['eyesight(right)'])
    best = np.where(df['eyesight(left)'] < df['eyesight(right)'], 
                    df['eyesight(left)'],  df['eyesight(right)'])
    worst = np.where(df['eyesight(left)'] < df['eyesight(right)'], 
                     df['eyesight(right)'],  df['eyesight(left)'])
    df['eyesight(left)'] = best
    df['eyesight(right)'] = worst
    ##
    df['Gtp'] = np.clip(df['Gtp'], 0, 300)
    df['HDL'] = np.clip(df['HDL'], 0, 110)
    df['LDL'] = np.clip(df['LDL'], 0, 200)
    df['ALT'] = np.clip(df['ALT'], 0, 150)
    df['AST'] = np.clip(df['AST'], 0, 100)
    df['serum creatinine'] = np.clip(df['serum creatinine'], 0, 3)  
    
    return df
train=create_extra_features(train)
test=create_extra_features(test)

# %% [markdown]
# <div style="background-color: #DDDDDD; padding: 20px; border-radius: 20px; border: 2px solid black;">
#     <h1 style="font-family:  'Garamond', 'Lucida Sans', sans-serif; text-align: center; color: black; font-weight: bold; font-size: 42px;">
#     Handle the Outliers
#     </h1>
# </div>

# %%
# # threshold functions
# def outlier_thresholds(dataframe, col_name, q1=0.01, q3=0.99):
#     quartile1 = dataframe[col_name].quantile(q1)
#     quartile3 = dataframe[col_name].quantile(q3)
#     interquantile_range = quartile3 - quartile1
#     up_limit = quartile3 + 1.5 * interquantile_range
#     low_limit = quartile1 - 1.5 * interquantile_range
#     return low_limit, up_limit

# def replace_with_thresholds(dataframe, variable):
#     low_limit, up_limit = outlier_thresholds(dataframe, variable)
#     dataframe.loc[(dataframe[variable] < low_limit), variable] = low_limit
#     dataframe.loc[(dataframe[variable] > up_limit), variable] = up_limit

# %%
X_th = train.drop(['id','smoking'],axis=1)
X_test_th = test.drop(['id'],axis=1)
y_th = train['smoking']

# %%
# for col in X_th.columns:
#     low_limit, up_limit = outlier_thresholds(X_th, col)
    
# for col in X_th.columns:
#     replace_with_thresholds(X_th, col)
    
# for col in X_test_th.columns:
#     low_limit, up_limit = outlier_thresholds(X_test_th, col)
    
# for col in X_test_th.columns:
#     replace_with_thresholds(X_test_th, col)

# %%
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.inspection import PartialDependenceDisplay

# %%
X = X_th
y = y_th
test_id = test['id']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=42)

# %% [markdown]
# <div style="background-color: #DDDDDD; padding: 20px; border-radius: 20px; border: 2px solid black;">
#     <h1 style="font-family:  'Garamond', 'Lucida Sans', sans-serif; text-align: center; color: black; font-weight: bold; font-size: 42px;">
#     Feature Transform
#     </h1>
# </div>

# %%
from sklearn.preprocessing import PowerTransformer
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline



# PowerTransformer ile standartlaştırma işlemi
stand_tran = make_pipeline(PowerTransformer())

# Sütunları seçin ve PowerTransformer ile dönüştürün
column_transformer = make_column_transformer(
    (stand_tran, ['age', 'height(cm)', 'weight(kg)', 'waist(cm)', 'eyesight(left)', 'eyesight(right)', 'systolic', 'relaxation', 'fasting blood sugar', 'Cholesterol', 'triglyceride', 'HDL', 'LDL', 'hemoglobin', 'serum creatinine', 'AST', 'ALT', 'Gtp']),
    remainder='passthrough'
)

# %% [markdown]
# <div style="background-color: #DDDDDD; padding: 20px; border-radius: 20px; border: 2px solid black;">
#     <h1 style="font-family:  'Garamond', 'Lucida Sans', sans-serif; text-align: center; color: black; font-weight: bold; font-size: 42px;">
#     Optuna
#     </h1>
# </div>

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_predict
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
import optuna
from sklearn.model_selection import train_test_split
import numpy as np
def objective(trial):
    xgb_params = {
        'n_estimators': trial.suggest_int('xgb_n_estimators', 50, 1000),
        'learning_rate': trial.suggest_float('xgb_learning_rate', 0.001, 0.1),
        'max_depth': trial.suggest_int('xgb_max_depth', 3, 10),
        'subsample': trial.suggest_float('xgb_subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('xgb_colsample_bytree', 0.6, 1.0),
        'verbosity': 0
    }

    cat_params = {
        'iterations': trial.suggest_int('cat_iterations', 50, 1000),
        'learning_rate': trial.suggest_float('cat_learning_rate', 0.001, 0.1),
        'depth': trial.suggest_int('cat_depth', 3, 10),
        'subsample': trial.suggest_float('cat_subsample', 0.6, 1.0),
        'colsample_bylevel': trial.suggest_float('cat_colsample_bylevel', 0.6, 1.0),
        'verbose': 0
    }

    lgbm_params = {
        'n_estimators': trial.suggest_int('lgbm_n_estimators', 50, 1000),
        'learning_rate': trial.suggest_float('lgbm_learning_rate', 0.001, 0.1),
        'max_depth': trial.suggest_int('lgbm_max_depth', 3, 10),
        'subsample': trial.suggest_float('lgbm_subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('lgbm_colsample_bytree', 0.6, 1.0),
        'verbosity': -1
    }

    xgb_model = XGBClassifier(**xgb_params)
    cat_model = CatBoostClassifier(**cat_params)
    lgbm_model = LGBMClassifier(**lgbm_params)

    # Modelleri bir listeye ekleyin
    modeller = [xgb_model, cat_model, lgbm_model]

    # Çapraz doğrulama yapın
    ensemble_tahminler = np.zeros(len(y))
    for model in modeller:
        # Çapraz doğrulama tahminlerini hesaplayın
        cv_tahminleri = cross_val_predict(model, X, y, cv=5,method='predict_proba')[:, 1]
        ensemble_tahminler += cv_tahminleri

    # Katların üzerinden tahminleri ortalama
    ensemble_tahminler /= len(modeller)

    # Pozitif MSE'yi hesaplayın
    mse = mean_squared_error(y, ensemble_tahminler)

    return mse

# Optuna'nın optimize fonksiyonunu kullanarak hiperparametre optimizasyonunu gerçekleştirin
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)

# En iyi hiperparametreleri alın
en_iyi_hiperparametreler = study.best_params
print("En İyi Hiperparametreler:", en_iyi_hiperparametreler)
# Out:
# [I 2023-11-11 00:43:34,708] A new study created in memory with name: no-name-8eec377b-dac2-4c56-b48c-0f7d63fe2a66
# [I 2023-11-11 00:44:33,689] Trial 0 finished with value: 0.14702496423163008 and parameters: {'xgb_n_estimators': 168, 'xgb_learning_rate': 0.02256915420082674, 'xgb_max_depth': 3, 'xgb_subsample': 0.7099521916357573, 'xgb_colsample_bytree': 0.7641885154564738, 'cat_iterations': 627, 'cat_learning_rate': 0.01665970292997135, 'cat_depth': 10, 'cat_subsample': 0.7220260554788692, 'cat_colsample_bylevel': 0.6672599697586407, 'lgbm_n_estimators': 601, 'lgbm_learning_rate': 0.09204764162262696, 'lgbm_max_depth': 5, 'lgbm_subsample': 0.6236464019360701, 'lgbm_colsample_bytree': 0.6727885586965724}. Best is trial 0 with value: 0.14702496423163008.
# [I 2023-11-11 00:44:54,356] Trial 1 finished with value: 0.14988183057368767 and parameters: {'xgb_n_estimators': 343, 'xgb_learning_rate': 0.06024097278310042, 'xgb_max_depth': 5, 'xgb_subsample': 0.6282360237027044, 'xgb_colsample_bytree': 0.8789860104576683, 'cat_iterations': 60, 'cat_learning_rate': 0.007828210419050366, 'cat_depth': 6, 'cat_subsample': 0.8601770701319504, 'cat_colsample_bylevel': 0.6967014582866771, 'lgbm_n_estimators': 662, 'lgbm_learning_rate': 0.05117966595162317, 'lgbm_max_depth': 6, 'lgbm_subsample': 0.8365636186241827, 'lgbm_colsample_bytree': 0.6643021578629877}. Best is trial 0 with value: 0.14702496423163008.
# [I 2023-11-11 00:45:27,082] Trial 2 finished with value: 0.14622928062457152 and parameters: {'xgb_n_estimators': 138, 'xgb_learning_rate': 0.07366222174952494, 'xgb_max_depth': 3, 'xgb_subsample': 0.9881826892080033, 'xgb_colsample_bytree': 0.915307162437487, 'cat_iterations': 719, 'cat_learning_rate': 0.05849973552902245, 'cat_depth': 3, 'cat_subsample': 0.6179769164428811, 'cat_colsample_bylevel': 0.818201621879272, 'lgbm_n_estimators': 997, 'lgbm_learning_rate': 0.07265289996193257, 'lgbm_max_depth': 10, 'lgbm_subsample': 0.6440065768717966, 'lgbm_colsample_bytree': 0.7158158000177302}. Best is trial 2 with value: 0.14622928062457152.
# [I 2023-11-11 00:45:49,217] Trial 3 finished with value: 0.14544556801142766 and parameters: {'xgb_n_estimators': 597, 'xgb_learning_rate': 0.06686081173561581, 'xgb_max_depth': 5, 'xgb_subsample': 0.7240566021425002, 'xgb_colsample_bytree': 0.8657465767489534, 'cat_iterations': 143, 'cat_learning_rate': 0.029812120093390505, 'cat_depth': 9, 'cat_subsample': 0.7253386962624965, 'cat_colsample_bylevel': 0.7582337483900655, 'lgbm_n_estimators': 393, 'lgbm_learning_rate': 0.08654854924795112, 'lgbm_max_depth': 10, 'lgbm_subsample': 0.8304135775185781, 'lgbm_colsample_bytree': 0.9841198490861255}. Best is trial 3 with value: 0.14544556801142766.
# [I 2023-11-11 00:46:40,609] Trial 4 finished with value: 0.14491333927654027 and parameters: {'xgb_n_estimators': 891, 'xgb_learning_rate': 0.06780245062317515, 'xgb_max_depth': 10, 'xgb_subsample': 0.7426706707529337, 'xgb_colsample_bytree': 0.8837865433937164, 'cat_iterations': 578, 'cat_learning_rate': 0.09464997349130702, 'cat_depth': 7, 'cat_subsample': 0.6040618313732137, 'cat_colsample_bylevel': 0.8401602590470133, 'lgbm_n_estimators': 325, 'lgbm_learning_rate': 0.01084315274037206, 'lgbm_max_depth': 9, 'lgbm_subsample': 0.8361627826794853, 'lgbm_colsample_bytree': 0.9884900681942049}. Best is trial 4 with value: 0.14491333927654027.
# [I 2023-11-11 00:47:00,218] Trial 5 finished with value: 0.14927941133920322 and parameters: {'xgb_n_estimators': 939, 'xgb_learning_rate': 0.0454048492743514, 'xgb_max_depth': 6, 'xgb_subsample': 0.9523978661895782, 'xgb_colsample_bytree': 0.6434935285432531, 'cat_iterations': 232, 'cat_learning_rate': 0.005160253454295949, 'cat_depth': 5, 'cat_subsample': 0.6846925735981962, 'cat_colsample_bylevel': 0.9908713011006344, 'lgbm_n_estimators': 131, 'lgbm_learning_rate': 0.07103797126817128, 'lgbm_max_depth': 3, 'lgbm_subsample': 0.8590910989278736, 'lgbm_colsample_bytree': 0.8170465193503921}. Best is trial 4 with value: 0.14491333927654027.
# [I 2023-11-11 00:47:55,122] Trial 6 finished with value: 0.14528462840515557 and parameters: {'xgb_n_estimators': 988, 'xgb_learning_rate': 0.010540678123340832, 'xgb_max_depth': 9, 'xgb_subsample': 0.651853910671406, 'xgb_colsample_bytree': 0.7008546849715084, 'cat_iterations': 856, 'cat_learning_rate': 0.07192022067922858, 'cat_depth': 4, 'cat_subsample': 0.8031763830238827, 'cat_colsample_bylevel': 0.9820759093246122, 'lgbm_n_estimators': 383, 'lgbm_learning_rate': 0.035098216447325366, 'lgbm_max_depth': 8, 'lgbm_subsample': 0.8332772484471708, 'lgbm_colsample_bytree': 0.7968677014796963}. Best is trial 4 with value: 0.14491333927654027.
# [I 2023-11-11 00:48:18,832] Trial 7 finished with value: 0.14627097907765618 and parameters: {'xgb_n_estimators': 684, 'xgb_learning_rate': 0.047286932878089626, 'xgb_max_depth': 5, 'xgb_subsample': 0.8345928275661748, 'xgb_colsample_bytree': 0.9031264896201895, 'cat_iterations': 254, 'cat_learning_rate': 0.022342414028194615, 'cat_depth': 3, 'cat_subsample': 0.8268454379337619, 'cat_colsample_bylevel': 0.7909648490451432, 'lgbm_n_estimators': 948, 'lgbm_learning_rate': 0.06375112984781811, 'lgbm_max_depth': 4, 'lgbm_subsample': 0.9463983236739597, 'lgbm_colsample_bytree': 0.9023281817775036}. Best is trial 4 with value: 0.14491333927654027.
# [I 2023-11-11 00:49:15,984] Trial 8 finished with value: 0.1451167447205006 and parameters: {'xgb_n_estimators': 276, 'xgb_learning_rate': 0.06492103436629897, 'xgb_max_depth': 10, 'xgb_subsample': 0.7150810743328933, 'xgb_colsample_bytree': 0.891671774736428, 'cat_iterations': 905, 'cat_learning_rate': 0.06830868185541082, 'cat_depth': 7, 'cat_subsample': 0.9186986557157577, 'cat_colsample_bylevel': 0.8320849082234196, 'lgbm_n_estimators': 695, 'lgbm_learning_rate': 0.0061954009026932485, 'lgbm_max_depth': 8, 'lgbm_subsample': 0.6548724602678159, 'lgbm_colsample_bytree': 0.6440361955793535}. Best is trial 4 with value: 0.14491333927654027.
# [I 2023-11-11 00:49:58,352] Trial 9 finished with value: 0.14441079905651139 and parameters: {'xgb_n_estimators': 979, 'xgb_learning_rate': 0.06295354628927312, 'xgb_max_depth': 10, 'xgb_subsample': 0.7168054723509799, 'xgb_colsample_bytree': 0.6223751874403953, 'cat_iterations': 160, 'cat_learning_rate': 0.08699777301693663, 'cat_depth': 3, 'cat_subsample': 0.7667455162448252, 'cat_colsample_bylevel': 0.903418901838682, 'lgbm_n_estimators': 922, 'lgbm_learning_rate': 0.09116702345547828, 'lgbm_max_depth': 8, 'lgbm_subsample': 0.6703819344758186, 'lgbm_colsample_bytree': 0.6390550939587355}. Best is trial 9 with value: 0.14441079905651139.
# [I 2023-11-11 00:50:38,116] Trial 10 finished with value: 0.14379368243007415 and parameters: {'xgb_n_estimators': 771, 'xgb_learning_rate': 0.09825683147189458, 'xgb_max_depth': 8, 'xgb_subsample': 0.8263091274536779, 'xgb_colsample_bytree': 0.613964175905447, 'cat_iterations': 432, 'cat_learning_rate': 0.08625559677709943, 'cat_depth': 5, 'cat_subsample': 0.9778610829028236, 'cat_colsample_bylevel': 0.9220527552178086, 'lgbm_n_estimators': 817, 'lgbm_learning_rate': 0.09238403834838876, 'lgbm_max_depth': 7, 'lgbm_subsample': 0.7232087431200618, 'lgbm_colsample_bytree': 0.6105271187534087}. Best is trial 10 with value: 0.14379368243007415.
# [I 2023-11-11 00:51:19,426] Trial 11 finished with value: 0.14375117811769744 and parameters: {'xgb_n_estimators': 743, 'xgb_learning_rate': 0.09593501147252168, 'xgb_max_depth': 8, 'xgb_subsample': 0.8277000794956482, 'xgb_colsample_bytree': 0.6041716395876502, 'cat_iterations': 458, 'cat_learning_rate': 0.09930688183372426, 'cat_depth': 5, 'cat_subsample': 0.9796972941077936, 'cat_colsample_bylevel': 0.907042715391487, 'lgbm_n_estimators': 816, 'lgbm_learning_rate': 0.09821883428727914, 'lgbm_max_depth': 7, 'lgbm_subsample': 0.7157040145736945, 'lgbm_colsample_bytree': 0.6087580937352026}. Best is trial 11 with value: 0.14375117811769744.
# [I 2023-11-11 00:51:56,551] Trial 12 finished with value: 0.14375272282392934 and parameters: {'xgb_n_estimators': 751, 'xgb_learning_rate': 0.09957203097909582, 'xgb_max_depth': 8, 'xgb_subsample': 0.8396929664358534, 'xgb_colsample_bytree': 0.6100384557618955, 'cat_iterations': 407, 'cat_learning_rate': 0.09587318976680113, 'cat_depth': 5, 'cat_subsample': 0.998808380919183, 'cat_colsample_bylevel': 0.9152876103583356, 'lgbm_n_estimators': 746, 'lgbm_learning_rate': 0.09805551159974997, 'lgbm_max_depth': 6, 'lgbm_subsample': 0.7273648820785691, 'lgbm_colsample_bytree': 0.6211950014201681}. Best is trial 11 with value: 0.14375117811769744.
# [I 2023-11-11 00:52:30,349] Trial 13 finished with value: 0.14382863011275449 and parameters: {'xgb_n_estimators': 488, 'xgb_learning_rate': 0.09930452823157669, 'xgb_max_depth': 8, 'xgb_subsample': 0.8651907691803857, 'xgb_colsample_bytree': 0.6937738003247026, 'cat_iterations': 427, 'cat_learning_rate': 0.09995309404960412, 'cat_depth': 5, 'cat_subsample': 0.9933941944555814, 'cat_colsample_bylevel': 0.9014392175128899, 'lgbm_n_estimators': 768, 'lgbm_learning_rate': 0.09979325044449745, 'lgbm_max_depth': 6, 'lgbm_subsample': 0.7426928808052393, 'lgbm_colsample_bytree': 0.6058205706369897}. Best is trial 11 with value: 0.14375117811769744.
# [I 2023-11-11 00:53:14,282] Trial 14 finished with value: 0.14370744822475848 and parameters: {'xgb_n_estimators': 788, 'xgb_learning_rate': 0.08549517027305473, 'xgb_max_depth': 7, 'xgb_subsample': 0.8918498785569339, 'xgb_colsample_bytree': 0.675875842245408, 'cat_iterations': 437, 'cat_learning_rate': 0.07913944180613594, 'cat_depth': 8, 'cat_subsample': 0.9316226440584413, 'cat_colsample_bylevel': 0.9317074907240999, 'lgbm_n_estimators': 824, 'lgbm_learning_rate': 0.07816480575839255, 'lgbm_max_depth': 5, 'lgbm_subsample': 0.7494732008304313, 'lgbm_colsample_bytree': 0.7137137267838627}. Best is trial 14 with value: 0.14370744822475848.
# [I 2023-11-11 00:53:42,491] Trial 15 finished with value: 0.14440343094014985 and parameters: {'xgb_n_estimators': 503, 'xgb_learning_rate': 0.08463881586084168, 'xgb_max_depth': 7, 'xgb_subsample': 0.8884206313023061, 'xgb_colsample_bytree': 0.6848583538878863, 'cat_iterations': 309, 'cat_learning_rate': 0.08081285489891853, 'cat_depth': 8, 'cat_subsample': 0.9220996546483747, 'cat_colsample_bylevel': 0.6261283263450355, 'lgbm_n_estimators': 528, 'lgbm_learning_rate': 0.07957403829437588, 'lgbm_max_depth': 4, 'lgbm_subsample': 0.7763184453639497, 'lgbm_colsample_bytree': 0.7184333577620249}. Best is trial 14 with value: 0.14370744822475848.
# [I 2023-11-11 00:54:37,336] Trial 16 finished with value: 0.1436335133774579 and parameters: {'xgb_n_estimators': 799, 'xgb_learning_rate': 0.08444569451163439, 'xgb_max_depth': 7, 'xgb_subsample': 0.9069719815772848, 'xgb_colsample_bytree': 0.7618121883320094, 'cat_iterations': 721, 'cat_learning_rate': 0.049971195935761145, 'cat_depth': 8, 'cat_subsample': 0.926185729287704, 'cat_colsample_bylevel': 0.9498159382986548, 'lgbm_n_estimators': 864, 'lgbm_learning_rate': 0.08070197670413284, 'lgbm_max_depth': 5, 'lgbm_subsample': 0.6004845181057471, 'lgbm_colsample_bytree': 0.7070674227288473}. Best is trial 16 with value: 0.1436335133774579.
# [I 2023-11-11 00:55:41,625] Trial 17 finished with value: 0.14390542728800582 and parameters: {'xgb_n_estimators': 859, 'xgb_learning_rate': 0.08218825753156084, 'xgb_max_depth': 6, 'xgb_subsample': 0.9039844916026951, 'xgb_colsample_bytree': 0.989380458570173, 'cat_iterations': 707, 'cat_learning_rate': 0.04203873213903913, 'cat_depth': 9, 'cat_subsample': 0.8844185574770083, 'cat_colsample_bylevel': 0.961643884766517, 'lgbm_n_estimators': 895, 'lgbm_learning_rate': 0.05870506422124441, 'lgbm_max_depth': 5, 'lgbm_subsample': 0.6023595093150255, 'lgbm_colsample_bytree': 0.7321385731409331}. Best is trial 16 with value: 0.1436335133774579.
# [I 2023-11-11 00:56:36,774] Trial 18 finished with value: 0.14534262532625075 and parameters: {'xgb_n_estimators': 613, 'xgb_learning_rate': 0.08243163100884308, 'xgb_max_depth': 7, 'xgb_subsample': 0.9267591244436316, 'xgb_colsample_bytree': 0.7635622678898222, 'cat_iterations': 1000, 'cat_learning_rate': 0.048109927585088724, 'cat_depth': 8, 'cat_subsample': 0.9251446420598242, 'cat_colsample_bylevel': 0.9516129742074851, 'lgbm_n_estimators': 55, 'lgbm_learning_rate': 0.08293555183536176, 'lgbm_max_depth': 3, 'lgbm_subsample': 0.6780688878845709, 'lgbm_colsample_bytree': 0.7619559500908585}. Best is trial 16 with value: 0.1436335133774579.
# [I 2023-11-11 00:57:49,876] Trial 19 finished with value: 0.1442571287145413 and parameters: {'xgb_n_estimators': 837, 'xgb_learning_rate': 0.0877987430031425, 'xgb_max_depth': 4, 'xgb_subsample': 0.9370411004182636, 'xgb_colsample_bytree': 0.7410353858590308, 'cat_iterations': 739, 'cat_learning_rate': 0.058060871137909614, 'cat_depth': 10, 'cat_subsample': 0.8681675509640226, 'cat_colsample_bylevel': 0.8660665744067702, 'lgbm_n_estimators': 524, 'lgbm_learning_rate': 0.07603393400257409, 'lgbm_max_depth': 5, 'lgbm_subsample': 0.6005307146055371, 'lgbm_colsample_bytree': 0.6947133017789521}. Best is trial 16 with value: 0.1436335133774579.
# [I 2023-11-11 00:58:36,640] Trial 20 finished with value: 0.1440323348885314 and parameters: {'xgb_n_estimators': 640, 'xgb_learning_rate': 0.07568515091656866, 'xgb_max_depth': 7, 'xgb_subsample': 0.7859088905470764, 'xgb_colsample_bytree': 0.7997347201593752, 'cat_iterations': 538, 'cat_learning_rate': 0.04135968788923434, 'cat_depth': 8, 'cat_subsample': 0.9404805824206076, 'cat_colsample_bylevel': 0.8710448073617445, 'lgbm_n_estimators': 853, 'lgbm_learning_rate': 0.0659694068544553, 'lgbm_max_depth': 5, 'lgbm_subsample': 0.691272268521911, 'lgbm_colsample_bytree': 0.759410149783778}. Best is trial 16 with value: 0.1436335133774579.
# [I 2023-11-11 00:59:21,998] Trial 21 finished with value: 0.14388093687235756 and parameters: {'xgb_n_estimators': 762, 'xgb_learning_rate': 0.08804816147888188, 'xgb_max_depth': 9, 'xgb_subsample': 0.8788722683959014, 'xgb_colsample_bytree': 0.6487630483309116, 'cat_iterations': 481, 'cat_learning_rate': 0.07620941574358638, 'cat_depth': 6, 'cat_subsample': 0.9490067004631259, 'cat_colsample_bylevel': 0.945336661136031, 'lgbm_n_estimators': 823, 'lgbm_learning_rate': 0.08227204061427058, 'lgbm_max_depth': 7, 'lgbm_subsample': 0.7036233576329171, 'lgbm_colsample_bytree': 0.6764576136927073}. Best is trial 16 with value: 0.1436335133774579.
# [I 2023-11-11 01:00:07,838] Trial 22 finished with value: 0.14387739521052162 and parameters: {'xgb_n_estimators': 806, 'xgb_learning_rate': 0.0920152161204214, 'xgb_max_depth': 8, 'xgb_subsample': 0.792121239151883, 'xgb_colsample_bytree': 0.6580476616541439, 'cat_iterations': 649, 'cat_learning_rate': 0.06585581341899518, 'cat_depth': 7, 'cat_subsample': 0.8961727973224838, 'cat_colsample_bylevel': 0.998764727972614, 'lgbm_n_estimators': 630, 'lgbm_learning_rate': 0.08399096700231971, 'lgbm_max_depth': 4, 'lgbm_subsample': 0.7664758384733844, 'lgbm_colsample_bytree': 0.6486610388878078}. Best is trial 16 with value: 0.1436335133774579.
# [I 2023-11-11 01:00:52,225] Trial 23 finished with value: 0.14380413777184606 and parameters: {'xgb_n_estimators': 673, 'xgb_learning_rate': 0.08961023701306542, 'xgb_max_depth': 6, 'xgb_subsample': 0.9091432978797228, 'xgb_colsample_bytree': 0.6003014404003757, 'cat_iterations': 372, 'cat_learning_rate': 0.08726050572981205, 'cat_depth': 9, 'cat_subsample': 0.965711065912273, 'cat_colsample_bylevel': 0.9385452985514149, 'lgbm_n_estimators': 997, 'lgbm_learning_rate': 0.09935515855266062, 'lgbm_max_depth': 7, 'lgbm_subsample': 0.649423983291217, 'lgbm_colsample_bytree': 0.6989746885697222}. Best is trial 16 with value: 0.1436335133774579.
# [I 2023-11-11 01:01:43,056] Trial 24 finished with value: 0.14378867493008748 and parameters: {'xgb_n_estimators': 553, 'xgb_learning_rate': 0.07805319756481546, 'xgb_max_depth': 9, 'xgb_subsample': 0.8625035173341548, 'xgb_colsample_bytree': 0.728861709913159, 'cat_iterations': 804, 'cat_learning_rate': 0.0774248935599351, 'cat_depth': 6, 'cat_subsample': 0.9562668116397561, 'cat_colsample_bylevel': 0.8803196772701176, 'lgbm_n_estimators': 741, 'lgbm_learning_rate': 0.07785044179706234, 'lgbm_max_depth': 6, 'lgbm_subsample': 0.7018624099137718, 'lgbm_colsample_bytree': 0.6083817608101085}. Best is trial 16 with value: 0.1436335133774579.
# [I 2023-11-11 01:02:22,337] Trial 25 finished with value: 0.14390523647623218 and parameters: {'xgb_n_estimators': 413, 'xgb_learning_rate': 0.09343819375416282, 'xgb_max_depth': 7, 'xgb_subsample': 0.9562057137525948, 'xgb_colsample_bytree': 0.6701570289020765, 'cat_iterations': 546, 'cat_learning_rate': 0.09173067557971792, 'cat_depth': 8, 'cat_subsample': 0.8997334684677601, 'cat_colsample_bylevel': 0.9619544218419047, 'lgbm_n_estimators': 861, 'lgbm_learning_rate': 0.09044734071573174, 'lgbm_max_depth': 4, 'lgbm_subsample': 0.755451756820831, 'lgbm_colsample_bytree': 0.6720164255076181}. Best is trial 16 with value: 0.1436335133774579.
# [I 2023-11-11 01:02:52,493] Trial 26 finished with value: 0.14421161493849793 and parameters: {'xgb_n_estimators': 716, 'xgb_learning_rate': 0.07716643297940565, 'xgb_max_depth': 8, 'xgb_subsample': 0.9131891655260281, 'xgb_colsample_bytree': 0.7124820903291458, 'cat_iterations': 340, 'cat_learning_rate': 0.08073240318386532, 'cat_depth': 4, 'cat_subsample': 0.9622399129140589, 'cat_colsample_bylevel': 0.9149630859977491, 'lgbm_n_estimators': 567, 'lgbm_learning_rate': 0.07383763398601516, 'lgbm_max_depth': 5, 'lgbm_subsample': 0.7872473511131515, 'lgbm_colsample_bytree': 0.6495088324734309}. Best is trial 16 with value: 0.1436335133774579.
# [I 2023-11-11 01:03:35,401] Trial 27 finished with value: 0.14371495599157652 and parameters: {'xgb_n_estimators': 893, 'xgb_learning_rate': 0.09092301166498401, 'xgb_max_depth': 6, 'xgb_subsample': 0.8817071846525919, 'xgb_colsample_bytree': 0.6762810194762693, 'cat_iterations': 489, 'cat_learning_rate': 0.09857410808478172, 'cat_depth': 7, 'cat_subsample': 0.9988336159008591, 'cat_colsample_bylevel': 0.8805902214302765, 'lgbm_n_estimators': 792, 'lgbm_learning_rate': 0.08765136127328368, 'lgbm_max_depth': 7, 'lgbm_subsample': 0.7174349158129883, 'lgbm_colsample_bytree': 0.6931525362106342}. Best is trial 16 with value: 0.1436335133774579.
# [I 2023-11-11 01:04:20,721] Trial 28 finished with value: 0.14390658591560754 and parameters: {'xgb_n_estimators': 905, 'xgb_learning_rate': 0.08391444693707704, 'xgb_max_depth': 6, 'xgb_subsample': 0.9980834055784942, 'xgb_colsample_bytree': 0.6772921457581575, 'cat_iterations': 620, 'cat_learning_rate': 0.06449934549899615, 'cat_depth': 7, 'cat_subsample': 0.9979382857929519, 'cat_colsample_bylevel': 0.8780946531604189, 'lgbm_n_estimators': 707, 'lgbm_learning_rate': 0.06656679788344308, 'lgbm_max_depth': 6, 'lgbm_subsample': 0.6329449415823762, 'lgbm_colsample_bytree': 0.7420335212520713}. Best is trial 16 with value: 0.1436335133774579.
# [I 2023-11-11 01:05:29,617] Trial 29 finished with value: 0.14437083346150176 and parameters: {'xgb_n_estimators': 838, 'xgb_learning_rate': 0.05805416052930529, 'xgb_max_depth': 4, 'xgb_subsample': 0.8870970948392092, 'xgb_colsample_bytree': 0.7397160785157407, 'cat_iterations': 643, 'cat_learning_rate': 0.09039209888871053, 'cat_depth': 10, 'cat_subsample': 0.9442368859263929, 'cat_colsample_bylevel': 0.9729419153312676, 'lgbm_n_estimators': 613, 'lgbm_learning_rate': 0.08650752196021419, 'lgbm_max_depth': 5, 'lgbm_subsample': 0.668950756767323, 'lgbm_colsample_bytree': 0.6890011989896415}. Best is trial 16 with value: 0.1436335133774579.
# [I 2023-11-11 01:06:19,150] Trial 30 finished with value: 0.143979189958009 and parameters: {'xgb_n_estimators': 951, 'xgb_learning_rate': 0.07036656750042948, 'xgb_max_depth': 5, 'xgb_subsample': 0.855558616571569, 'xgb_colsample_bytree': 0.7861798424828145, 'cat_iterations': 489, 'cat_learning_rate': 0.0727859062533734, 'cat_depth': 9, 'cat_subsample': 0.8617874098140625, 'cat_colsample_bylevel': 0.9384093881874683, 'lgbm_n_estimators': 934, 'lgbm_learning_rate': 0.07809221924196168, 'lgbm_max_depth': 4, 'lgbm_subsample': 0.6285618006920665, 'lgbm_colsample_bytree': 0.7087921576550984}. Best is trial 16 with value: 0.1436335133774579.
# [I 2023-11-11 01:07:06,880] Trial 31 finished with value: 0.14372844752847402 and parameters: {'xgb_n_estimators': 792, 'xgb_learning_rate': 0.09174649983454636, 'xgb_max_depth': 7, 'xgb_subsample': 0.8186368258732669, 'xgb_colsample_bytree': 0.6383443809764633, 'cat_iterations': 513, 'cat_learning_rate': 0.09994512515551078, 'cat_depth': 8, 'cat_subsample': 0.9769255390555174, 'cat_colsample_bylevel': 0.8927048649369856, 'lgbm_n_estimators': 792, 'lgbm_learning_rate': 0.0923644735188469, 'lgbm_max_depth': 7, 'lgbm_subsample': 0.7226435400644198, 'lgbm_colsample_bytree': 0.6796920326774083}. Best is trial 16 with value: 0.1436335133774579.
# [I 2023-11-11 01:07:58,520] Trial 32 finished with value: 0.14381192588173553 and parameters: {'xgb_n_estimators': 799, 'xgb_learning_rate': 0.09157442052445737, 'xgb_max_depth': 7, 'xgb_subsample': 0.9045089816403572, 'xgb_colsample_bytree': 0.6439650788166428, 'cat_iterations': 595, 'cat_learning_rate': 0.09914263336369004, 'cat_depth': 8, 'cat_subsample': 0.9723036113219826, 'cat_colsample_bylevel': 0.8511415475565345, 'lgbm_n_estimators': 781, 'lgbm_learning_rate': 0.09112574148655883, 'lgbm_max_depth': 8, 'lgbm_subsample': 0.7421552963807191, 'lgbm_colsample_bytree': 0.6624618146112906}. Best is trial 16 with value: 0.1436335133774579.
# [I 2023-11-11 01:08:38,447] Trial 33 finished with value: 0.14383757118328647 and parameters: {'xgb_n_estimators': 881, 'xgb_learning_rate': 0.07788307418149622, 'xgb_max_depth': 6, 'xgb_subsample': 0.8792041495122784, 'xgb_colsample_bytree': 0.7099862685392646, 'cat_iterations': 491, 'cat_learning_rate': 0.08299987410507911, 'cat_depth': 7, 'cat_subsample': 0.9268365395379082, 'cat_colsample_bylevel': 0.8920841761933307, 'lgbm_n_estimators': 677, 'lgbm_learning_rate': 0.08849079999672381, 'lgbm_max_depth': 6, 'lgbm_subsample': 0.6852588452115039, 'lgbm_colsample_bytree': 0.6859272440862033}. Best is trial 16 with value: 0.1436335133774579.
# [I 2023-11-11 01:09:27,492] Trial 34 finished with value: 0.14419114646213352 and parameters: {'xgb_n_estimators': 232, 'xgb_learning_rate': 0.09245091590803318, 'xgb_max_depth': 7, 'xgb_subsample': 0.9555682575306248, 'xgb_colsample_bytree': 0.6730375980675516, 'cat_iterations': 693, 'cat_learning_rate': 0.09226567138086349, 'cat_depth': 8, 'cat_subsample': 0.9485990844304205, 'cat_colsample_bylevel': 0.9289230954449423, 'lgbm_n_estimators': 897, 'lgbm_learning_rate': 0.0829726816911599, 'lgbm_max_depth': 9, 'lgbm_subsample': 0.7994051407435865, 'lgbm_colsample_bytree': 0.7221100641842956}. Best is trial 16 with value: 0.1436335133774579.
# [W 2023-11-11 01:10:10,997] Trial 35 failed with parameters: {'xgb_n_estimators': 693, 'xgb_learning_rate': 0.07375549491120033, 'xgb_max_depth': 6, 'xgb_subsample': 0.8177164209182688, 'xgb_colsample_bytree': 0.6315029931995944, 'cat_iterations': 781, 'cat_learning_rate': 0.09302496633983663, 'cat_depth': 9, 'cat_subsample': 0.8943566902769273, 'cat_colsample_bylevel': 0.8594079179736993, 'lgbm_n_estimators': 475, 'lgbm_learning_rate': 0.07181617418829275, 'lgbm_max_depth': 7, 'lgbm_subsample': 0.6546254567728437, 'lgbm_colsample_bytree': 0.669039018315028} because of the following error: KeyboardInterrupt('').
# Traceback (most recent call last):
#   File "/Users/murat/anaconda3/lib/python3.11/site-packages/optuna/study/_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/var/folders/_s/06b_lqd104n0zq3n4hjc1t7c0000gn/T/ipykernel_38534/3296366920.py", line 48, in objective
#     cv_tahminleri = cross_val_predict(model, X, y, cv=5,method='predict_proba')[:, 1]
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/murat/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 986, in cross_val_predict
#     predictions = parallel(
#                   ^^^^^^^^^
#   File "/Users/murat/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 63, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/murat/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1088, in __call__
#     while self.dispatch_one_batch(iterator):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/murat/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/murat/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/murat/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/murat/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "/Users/murat/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/murat/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/murat/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/murat/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 1068, in _fit_and_predict
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/murat/anaconda3/lib/python3.11/site-packages/catboost/core.py", line 5100, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "/Users/murat/anaconda3/lib/python3.11/site-packages/catboost/core.py", line 2319, in _fit
#     self._train(
#   File "/Users/murat/anaconda3/lib/python3.11/site-packages/catboost/core.py", line 1723, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#   File "_catboost.pyx", line 4645, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 4694, in _catboost._CatBoost._train
# KeyboardInterrupt
# [W 2023-11-11 01:10:11,003] Trial 35 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/murat/Desktop/binary/binary-pred.ipynb Hücre 17 line 6
#      <a href='vscode-notebook-cell:/Users/murat/Desktop/binary/binary-pred.ipynb#X52sZmlsZQ%3D%3D?line=58'>59</a> # Optuna'nın optimize fonksiyonunu kullanarak hiperparametre optimizasyonunu gerçekleştirin
#      <a href='vscode-notebook-cell:/Users/murat/Desktop/binary/binary-pred.ipynb#X52sZmlsZQ%3D%3D?line=59'>60</a> study = optuna.create_study(direction='minimize')
# ---> <a href='vscode-notebook-cell:/Users/murat/Desktop/binary/binary-pred.ipynb#X52sZmlsZQ%3D%3D?line=60'>61</a> study.optimize(objective, n_trials=100)
#      <a href='vscode-notebook-cell:/Users/murat/Desktop/binary/binary-pred.ipynb#X52sZmlsZQ%3D%3D?line=62'>63</a> # En iyi hiperparametreleri alın
#      <a href='vscode-notebook-cell:/Users/murat/Desktop/binary/binary-pred.ipynb#X52sZmlsZQ%3D%3D?line=63'>64</a> en_iyi_hiperparametreler = study.best_params
#
# File ~/anaconda3/lib/python3.11/site-packages/optuna/study/study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File ~/anaconda3/lib/python3.11/site-packages/optuna/study/_optimize.py:66, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64 try:
#      65     if n_jobs == 1:
# ---> 66         _optimize_sequential(
#      67             study,
#      68             func,
#      69             n_trials,
#      70             timeout,
#      71             catch,
#      72             callbacks,
#      73             gc_after_trial,
#      74             reseed_sampler_rng=False,
#      75             time_start=None,
#      76             progress_bar=progress_bar,
#      77         )
#      78     else:
#      79         if n_jobs == -1:
#
# File ~/anaconda3/lib/python3.11/site-packages/optuna/study/_optimize.py:163, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160         break
#     162 try:
# --> 163     frozen_trial = _run_trial(study, func, catch)
#     164 finally:
#     165     # The following line mitigates memory problems that can be occurred in some
#     166     # environments (e.g., services that use computing containers such as GitHub Actions).
#     167     # Please refer to the following PR for further details:
#     168     # https://github.com/optuna/optuna/pull/325.
#     169     if gc_after_trial:
#
# File ~/anaconda3/lib/python3.11/site-packages/optuna/study/_optimize.py:251, in _run_trial(study, func, catch)
#     244         assert False, "Should not reach."
#     246 if (
#     247     frozen_trial.state == TrialState.FAIL
#     248     and func_err is not None
#     249     and not isinstance(func_err, catch)
#     250 ):
# --> 251     raise func_err
#     252 return frozen_trial
#
# File ~/anaconda3/lib/python3.11/site-packages/optuna/study/_optimize.py:200, in _run_trial(study, func, catch)
#     198 with get_heartbeat_thread(trial._trial_id, study._storage):
#     199     try:
# --> 200         value_or_values = func(trial)
#     201     except exceptions.TrialPruned as e:
#     202         # TODO(mamu): Handle multi-objective cases.
#     203         state = TrialState.PRUNED
#
# /Users/murat/Desktop/binary/binary-pred.ipynb Hücre 17 line 4
#      <a href='vscode-notebook-cell:/Users/murat/Desktop/binary/binary-pred.ipynb#X52sZmlsZQ%3D%3D?line=44'>45</a> ensemble_tahminler = np.zeros(len(y))
#      <a href='vscode-notebook-cell:/Users/murat/Desktop/binary/binary-pred.ipynb#X52sZmlsZQ%3D%3D?line=45'>46</a> for model in modeller:
#      <a href='vscode-notebook-cell:/Users/murat/Desktop/binary/binary-pred.ipynb#X52sZmlsZQ%3D%3D?line=46'>47</a>     # Çapraz doğrulama tahminlerini hesaplayın
# ---> <a href='vscode-notebook-cell:/Users/murat/Desktop/binary/binary-pred.ipynb#X52sZmlsZQ%3D%3D?line=47'>48</a>     cv_tahminleri = cross_val_predict(model, X, y, cv=5,method='predict_proba')[:, 1]
#      <a href='vscode-notebook-cell:/Users/murat/Desktop/binary/binary-pred.ipynb#X52sZmlsZQ%3D%3D?line=48'>49</a>     ensemble_tahminler += cv_tahminleri
#      <a href='vscode-notebook-cell:/Users/murat/Desktop/binary/binary-pred.ipynb#X52sZmlsZQ%3D%3D?line=50'>51</a> # Katların üzerinden tahminleri ortalama
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:986, in cross_val_predict(estimator, X, y, groups, cv, n_jobs, verbose, fit_params, pre_dispatch, method)
#     983 # We clone the estimator to make sure that all the folds are
#     984 # independent, and that it is pickle-able.
#     985 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 986 predictions = parallel(
#     987     delayed(_fit_and_predict)(
#     988         clone(estimator), X, y, train, test, verbose, fit_params, method
#     989     )
#     990     for train, test in splits
#     991 )
#     993 inv_test_indices = np.empty(len(test_indices), dtype=int)
#     994 inv_test_indices[test_indices] = np.arange(len(test_indices))
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:1068, in _fit_and_predict(estimator, X, y, train, test, verbose, fit_params, method)
#    1066     estimator.fit(X_train, **fit_params)
#    1067 else:
# -> 1068     estimator.fit(X_train, y_train, **fit_params)
#    1069 func = getattr(estimator, method)
#    1070 predictions = func(X_test)
#
# File ~/anaconda3/lib/python3.11/site-packages/catboost/core.py:5100, in CatBoostClassifier.fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5097 if 'loss_function' in params:
#    5098     CatBoostClassifier._check_is_compatible_loss(params['loss_function'])
# -> 5100 self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#    5101           eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period,
#    5102           silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5103 return self
#
# File ~/anaconda3/lib/python3.11/site-packages/catboost/core.py:2319, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2315 allow_clear_pool = train_params["allow_clear_pool"]
#    2317 with log_fixup(log_cout, log_cerr), \
#    2318     plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(self.get_params())]):
# -> 2319     self._train(
#    2320         train_pool,
#    2321         train_params["eval_sets"],
#    2322         params,
#    2323         allow_clear_pool,
#    2324         train_params["init_model"]
#    2325     )
#    2327 # Have property feature_importance possibly set
#    2328 loss = self._object._get_loss_function_name()
#
# File ~/anaconda3/lib/python3.11/site-packages/catboost/core.py:1723, in _CatBoostBase._train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1722 def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1723     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1724     self._set_trained_model_attributes()
#
# File _catboost.pyx:4645, in _catboost._CatBoost._train()
#
# File _catboost.pyx:4694, in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
best_params = study.best_params
print("En iyi hiperparametreler:", best_params)

best_xgb_model = XGBClassifier(
    n_estimators=best_params['xgb_n_estimators'],
    learning_rate=best_params['xgb_learning_rate'],
    max_depth=best_params['xgb_max_depth'],
    subsample=best_params['xgb_subsample'],
    colsample_bytree=best_params['xgb_colsample_bytree']
)

best_cat_model = CatBoostClassifier(
    iterations=best_params['cat_iterations'],
    learning_rate=best_params['cat_learning_rate'],
    depth=best_params['cat_depth'],
    subsample=best_params['cat_subsample'],
    colsample_bylevel=best_params['cat_colsample_bylevel']
)

best_lgbm_model = LGBMClassifier(
    n_estimators=best_params['lgbm_n_estimators'],
    learning_rate=best_params['lgbm_learning_rate'],
    max_depth=best_params['lgbm_max_depth'],
    subsample=best_params['lgbm_subsample'],
    colsample_bytree=best_params['lgbm_colsample_bytree']
)
best_xgb_model.fit(X, y)
best_cat_model.fit(X, y)
best_lgbm_model.fit(X, y)

y_proba_xgb = best_xgb_model.predict_proba(X_test_th)[:, 1]
y_proba_cat = best_cat_model.predict_proba(X_test_th)[:, 1]
y_proba_lgbm = best_lgbm_model.predict_proba(X_test_th)[:, 1]

ensemble_predictions_proba = (y_proba_xgb + y_proba_cat + y_proba_lgbm) / 3

ensemble_predictions = ensemble_predictions_proba

# %%
predsVC = ensemble_predictions

# %%
result = pd.DataFrame({'id': test_id, 'prediction': predsVC})

result.to_csv('submission.csv', index=False)  # Tahmin sonuçlarını bir CSV dosyasına kaydetme

# %%
result
